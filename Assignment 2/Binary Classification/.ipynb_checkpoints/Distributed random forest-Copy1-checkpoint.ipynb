# %% [markdown]
# ## Distributed Random Forest

# %%
import h2o
from h2o.automl import H2OAutoML
import random, os, sys
from datetime import datetime
import pandas as pd
import logging
import csv
import optparse
import time
import json
from distutils.util import strtobool

# %% [markdown]
# Define all the starter functions

# %%
def impute_missing_values(df, x, scal=False):
    # determine column types
    ints, reals, enums = [], [], []
    for key, val in df.types.items():
        if key in x:
            if val == 'enum':
                enums.append(key)
            elif val == 'int':
                ints.append(key)            
            else: 
                reals.append(key)    
    _ = df[reals].impute(method='mean')
    _ = df[ints].impute(method='median')
    if scal:
        df[reals] = df[reals].scale()
        df[ints] = df[ints].scale()    
    return


def get_independent_variables(df, targ):
    C = [name for name in df.columns if name != targ]
    # determine column types
    ints, reals, enums = [], [], []
    for key, val in df.types.items():
        if key in C:
            if val == 'enum':
                enums.append(key)
            elif val == 'int':
                ints.append(key)            
            else: 
                reals.append(key)    
    x=ints+enums+reals
    return x
    
def get_all_variables_csv(i):
    ivd={}
    try:
        iv = pd.read_csv(i,header=None)
    except:
        sys.exit(1)    
    col=iv.values.tolist()[0]
    dt=iv.values.tolist()[1]
    i=0
    for c in col:
        ivd[c.strip()]=dt[i].strip()
        i+=1        
    return ivd
    
    

def check_all_variables(df,dct,y=None):     
    targ=list(dct.keys())     
    for key, val in df.types.items():
        if key in targ:
            if dct[key] not in ['real','int','enum']:                      
                targ.remove(key)  
    for key, val in df.types.items():
        if key in targ:            
            if dct[key] != val:
                print('convert ',key,' ',dct[key],' ',val)
            if dct[key]=='enum':
                try:
                    df[key] = df[key].asfactor() 
                except:
                    targ.remove(key)                 
            if dct[key]=='int': 
                try:                
                    df[key] = df[key].asnumeric() 
                except:
                    targ.remove(key)                  
            if dct[key]=='real':
                try:                
                    df[key] = df[key].asnumeric()  
                except:
                    targ.remove(key)                  
    if y is None:
        y=df.columns[-1] 
    if y in targ:
        targ.remove(y)
    else:
        y=targ.pop()            
    return targ

def check_X(x,df):
    for name in x:
        if name not in df.columns:
            x.remove(name)  
    return x

# %% [markdown]
# Initialize H2O

# %%
port_no=random.randint(5555,55555)
h2o.init(strict_version_check=False,min_mem_size_GB=6,port=port_no)
# Out:
# Checking whether there is an H2O instance running at http://localhost:43946..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.141-b15, mixed mode)
#   Starting server from C:\ProgramData\Anaconda3\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\raksh\AppData\Local\Temp\tmpo6owlues
#   JVM stdout: C:\Users\raksh\AppData\Local\Temp\tmpo6owlues\h2o_raksha_started_from_python.out
#   JVM stderr: C:\Users\raksh\AppData\Local\Temp\tmpo6owlues\h2o_raksha_started_from_python.err
#   Server is running at http://127.0.0.1:43946
# Connecting to H2O server at http://127.0.0.1:43946... successful.
# --------------------------  -------------------------------
# H2O cluster uptime:         03 secs
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.20.0.8
# H2O cluster version age:    24 days
# H2O cluster name:           H2O_from_python_raksha_bwhldl
# H2O cluster total nodes:    1
# H2O cluster free memory:    5.750 Gb
# H2O cluster total cores:    4
# H2O cluster allowed cores:  4
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:43946
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Algos, AutoML, Core V3, Core V4
# Python version:             3.6.5 final
# --------------------------  -------------------------------

# %% [markdown]
# Import data

# %%
df = h2o.import_file("cleanData.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
all_variables=None
scale=False

# %% [markdown]
# Define Target variables

# %%
y = "CLASS"

# %%
df[y] = df[y].asfactor()

# %%
if all_variables is not None:
    ivd=get_all_variables_csv(all_variables)
    print(ivd)    
    X=check_all_variables(df,ivd,y)
    print(X)

# %%
X = []  
if all_variables is None:
    X=get_independent_variables(df, y)  
else: 
    ivd=get_all_variables_csv(all_variables)    
    X=check_all_variables(df, ivd)


X=check_X(X,df)


# Add independent variables

#meta_data['X']=X  


# impute missing values

_=impute_missing_values(df,X, scale)

# %% [markdown]
# Split the dataset and run the model for train and test

# %%
train, test = df.split_frame([0.9])

# %%
from h2o.estimators.random_forest import H2ORandomForestEstimator
drf = H2ORandomForestEstimator()
drf.train(x=X, y = y, training_frame=train, validation_frame=test)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %% [markdown]
# ### Plots and Metrics

# %%
drf.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.26166548081750546:
#        0      1      Error    Rate
# -----  -----  -----  -------  -----------------
# 0      21844  8531   0.2809   (8531.0/30375.0)
# 1      2653   7169   0.2701   (2653.0/9822.0)
# Total  24497  15700  0.2782   (11184.0/40197.0)

# %%
drf.gains_lift
# Out:
# Model Details
# =============
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_logloss    training_auc    training_lift    training_classification_error    validation_rmse    validation_logloss    validation_auc    validation_lift    validation_classification_error
# --  -------------------  ----------  -----------------  ---------------  ------------------  --------------  ---------------  -------------------------------  -----------------  --------------------  ----------------  -----------------  ---------------------------------
#     2018-10-16 14:39:04  0.061 sec   0                  nan              nan                 nan             nan              nan                              nan                nan                   nan               nan                nan
#     2018-10-16 14:39:07  2.428 sec   1                  0.495976         6.69289             0.617906        1.85234          0.294626                         0.4937             6.53761               0.631132          1.95167            0.294857
#     2018-10-16 14:39:08  3.272 sec   2                  0.487137         6.19432             0.6359          1.89937          0.298954                         0.440547           3.06328               0.690722          2.29093            0.293714
#     2018-10-16 14:39:08  3.991 sec   3                  0.475617         5.53119             0.655273        1.94501          0.311311                         0.420437           1.77071               0.725611          2.49045            0.336229
#     2018-10-16 14:39:25  20.171 sec  40                 0.382891         0.490602            0.791917        3.53262          0.281837                         0.376768           0.441372              0.811361          3.5148             0.247086
#     2018-10-16 14:39:28  23.682 sec  50                 0.379966         0.463601            0.799809        3.50208          0.27823                          0.375312           0.437006              0.815845          3.4223             0.245257
# Variable Importances:
# variable     relative_importance    scaled_importance      percentage
# -----------  ---------------------  ---------------------  ----------------------
# Amino_acids  36546.46875            1.0                    0.18852738216589696
# CLNDN        13813.498046875        0.37797080044498144    0.071257845543041
# CLNVI        13422.552734375        0.3672735887615681     0.06924112822789263
# CLNDISDB     13246.494140625        0.36245619874355167    0.06833291829892386
# Codons       12280.5263671875       0.33602497825969846    0.06334990949365339
# ---          ---                    ---                    ---
# IMPACT       1124.557373046875      0.030770616464740524   0.005801103769728378
# STRAND       883.9725952148438      0.0241876335922289     0.004560031241930825
# ORIGIN       281.8144836425781      0.007711127594032682   0.001453758698850193
# CLNVC        136.3553009033203      0.003731011656312768   0.0007033978603950934
# BAM_EDIT     24.303546905517578     0.0006650039726619984  0.00012537145809588828
# See the whole table with table.as_data_frame()
# <bound method H2OBinomialModel.gains_lift of >

# %%
drf.varimp_plot(num_of_features=33)

# %%
drf.plot()

# %%
drf.model_performance().plot()

# %%
drf.partial_plot(data=df, cols=['CHROM','POS','AF_ESP','AF_EXAC','AF_TGP','ORIGIN','IMPACT'])
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'CHROM'
# chrom    mean_response    stddev_response    std_error_mean_response
# -------  ---------------  -----------------  -------------------------
# 1        0.24475          0.248963           0.00117924
# 2.10526  0.243415         0.25149            0.00119121
# 3.21053  0.242199         0.251914           0.00119322
# 4.31579  0.24187          0.252419           0.00119562
# 5.42105  0.24114          0.252671           0.00119681
# 6.52632  0.242954         0.252442           0.00119572
# 7.63158  0.24398          0.2529             0.00119789
# 8.73684  0.243141         0.252403           0.00119554
# 9.84211  0.242769         0.251948           0.00119339
# 10.9474  0.243415         0.25217            0.00119443
# 12.0526  0.243484         0.252105           0.00119413
# 13.1579  0.244306         0.251627           0.00119186
# 14.2632  0.245515         0.25146            0.00119107
# 15.3684  0.245844         0.250924           0.00118853
# 16.4737  0.245946         0.249813           0.00118327
# 17.5789  0.24604          0.248054           0.00117494
# 18.6842  0.246226         0.24591            0.00116478
# 19.7895  0.246335         0.243049           0.00115123
# 20.8947  0.24909          0.241712           0.0011449
# 22       0.250019         0.240067           0.00113711
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'POS'
# pos          mean_response    stddev_response    std_error_mean_response
# -----------  ---------------  -----------------  -------------------------
# 193245       0.251587         0.242484           0.00114855
# 1.32151e+07  0.248118         0.245685           0.00116372
# 2.62369e+07  0.245191         0.248037           0.00117486
# 3.92587e+07  0.244621         0.248346           0.00117632
# 5.22806e+07  0.239641         0.249034           0.00117958
# 6.53024e+07  0.239054         0.248855           0.00117873
# 7.83242e+07  0.238731         0.248869           0.0011788
# 9.1346e+07   0.238505         0.247948           0.00117444
# 1.04368e+08  0.237481         0.246478           0.00116747
# 1.1739e+08   0.239261         0.2451             0.00116095
# 1.30412e+08  0.240051         0.244022           0.00115584
# 1.43433e+08  0.25122          0.23278            0.00110259
# 1.56455e+08  0.251798         0.232784           0.00110261
# 1.69477e+08  0.255041         0.232088           0.00109931
# 1.82499e+08  0.255972         0.231131           0.00109478
# 1.95521e+08  0.256088         0.230121           0.00109
# 2.08542e+08  0.257357         0.22997            0.00108928
# 2.21564e+08  0.258663         0.229011           0.00108474
# 2.34586e+08  0.260879         0.227671           0.00107839
# 2.47608e+08  0.262886         0.226922           0.00107485
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'AF_ESP'
# af_esp     mean_response    stddev_response    std_error_mean_response
# ---------  ---------------  -----------------  -------------------------
# 0          0.24311          0.239378           0.00113384
# 0.0262632  0.194021         0.163427           0.000774092
# 0.0525263  0.191411         0.161265           0.000763851
# 0.0787895  0.181058         0.157171           0.00074446
# 0.105053   0.180848         0.157264           0.000744901
# 0.131316   0.180809         0.157212           0.000744655
# 0.157579   0.179942         0.156487           0.000741218
# 0.183842   0.178865         0.155654           0.000737277
# 0.210105   0.178836         0.155622           0.000737122
# 0.236368   0.178381         0.155157           0.000734919
# 0.262632   0.17831          0.15504            0.000734368
# 0.288895   0.17831          0.15504            0.000734368
# 0.315158   0.17831          0.15504            0.000734368
# 0.341421   0.17831          0.15504            0.000734368
# 0.367684   0.17831          0.15504            0.000734368
# 0.393947   0.17831          0.15504            0.000734368
# 0.420211   0.17831          0.15504            0.000734368
# 0.446474   0.17831          0.15504            0.000734368
# 0.472737   0.17831          0.15504            0.000734368
# 0.499      0.17831          0.15504            0.000734368
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'AF_EXAC'
# af_exac    mean_response    stddev_response    std_error_mean_response
# ---------  ---------------  -----------------  -------------------------
# 0          0.239512         0.248694           0.00117797
# 0.02631    0.236719         0.193468           0.000916384
# 0.05262    0.234028         0.19057            0.000902658
# 0.07893    0.232294         0.189326           0.000896765
# 0.10524    0.23198          0.189023           0.00089533
# 0.13155    0.2314           0.188469           0.000892708
# 0.15786    0.231393         0.188465           0.000892686
# 0.18417    0.231569         0.18838            0.000892284
# 0.21048    0.230204         0.186936           0.000885443
# 0.23679    0.229649         0.186384           0.000882831
# 0.2631     0.22941          0.18613            0.000881628
# 0.28941    0.22941          0.18613            0.000881628
# 0.31572    0.22941          0.18613            0.000881628
# 0.34203    0.229456         0.186113           0.000881548
# 0.36834    0.229456         0.186113           0.000881548
# 0.39465    0.229456         0.186113           0.000881548
# 0.42096    0.229456         0.186113           0.000881548
# 0.44727    0.229464         0.186107           0.000881518
# 0.47358    0.229629         0.185996           0.000880992
# 0.49989    0.231921         0.184766           0.000875167
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'AF_TGP'
# af_tgp     mean_response    stddev_response    std_error_mean_response
# ---------  ---------------  -----------------  -------------------------
# 0          0.256133         0.23802            0.00112741
# 0.0261474  0.159956         0.129665           0.000614176
# 0.0522947  0.156918         0.128789           0.000610024
# 0.0784421  0.155703         0.128471           0.000608519
# 0.104589   0.158351         0.127822           0.000605445
# 0.130737   0.158223         0.127684           0.000604792
# 0.156884   0.158223         0.127684           0.000604792
# 0.183032   0.157983         0.127583           0.000604311
# 0.209179   0.157979         0.127467           0.000603764
# 0.235326   0.157796         0.127413           0.000603508
# 0.261474   0.157188         0.127146           0.000602242
# 0.287621   0.157025         0.127105           0.000602047
# 0.313768   0.157021         0.127104           0.000602046
# 0.339916   0.157021         0.127104           0.000602046
# 0.366063   0.157021         0.127104           0.000602046
# 0.392211   0.157021         0.127104           0.000602046
# 0.418358   0.157021         0.127104           0.000602046
# 0.444505   0.157021         0.127104           0.000602046
# 0.470653   0.157021         0.127104           0.000602046
# 0.4968     0.157021         0.127104           0.000602046
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'ORIGIN'
# origin    mean_response    stddev_response    std_error_mean_response
# --------  ---------------  -----------------  -------------------------
# 0         0.241355         0.267727           0.00126812
# 27        0.267176         0.256044           0.00121278
# 54        0.267288         0.256015           0.00121265
# 81        0.267288         0.256015           0.00121265
# 108       0.267288         0.256015           0.00121265
# 135       0.267288         0.256015           0.00121265
# 162       0.267288         0.256015           0.00121265
# 189       0.267288         0.256015           0.00121265
# 216       0.267288         0.256015           0.00121265
# 243       0.267288         0.256015           0.00121265
# 270       0.269177         0.255186           0.00120872
# 297       0.269319         0.255163           0.00120861
# 324       0.269319         0.255163           0.00120861
# 351       0.269319         0.255163           0.00120861
# 378       0.269319         0.255163           0.00120861
# 405       0.269319         0.255163           0.00120861
# 432       0.269319         0.255163           0.00120861
# 459       0.269319         0.255163           0.00120861
# 486       0.269319         0.255163           0.00120861
# 513       0.269319         0.255163           0.00120861
# PartialDependence: Partial Dependence Plot of model DRF_model_python_1539714651704_1 on column 'IMPACT'
# impact    mean_response    stddev_response    std_error_mean_response
# --------  ---------------  -----------------  -------------------------
# HIGH      0.24659          0.237849           0.0011266
# LOW       0.248534         0.259821           0.00123068
# MODERATE  0.241747         0.258743           0.00122557
# [, , , , , , ]
