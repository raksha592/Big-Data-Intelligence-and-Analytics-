# %% [markdown]
# How is the data distributed? (10 %)

# %% [markdown]
# What are the summary statistics? (10 %)

# %% [markdown]
# Are there anomalies/outliers? (10 %)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv("cleanData.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#                 POS        AF_ESP       AF_EXAC        AF_TGP        ORIGIN  \
# count  4.457200e+04  44572.000000  44572.000000  44572.000000  44572.000000
# mean   8.010918e+07      0.010081      0.009889      0.010461      1.283923
# std    6.056906e+07      0.047918      0.049353      0.049282      5.950458
# min    1.932450e+05      0.000000      0.000000      0.000000      0.000000
# 25%    3.291106e+07      0.000000      0.000000      0.000000      1.000000
# 50%    6.172510e+07      0.000000      0.000030      0.000000      1.000000
# 75%    1.191568e+08      0.000700      0.000690      0.000800      1.000000
# max    2.476080e+08      0.499000      0.499890      0.496800    513.000000
#
#               CLASS        STRAND       LoFtool    CADD_PHRED      CADD_RAW
# count  44572.000000  44572.000000  44572.000000  44572.000000  44572.000000
# mean       0.244481      0.012519      0.356614     16.592506      2.775809
# std        0.429784      0.999933      0.366361     10.899270      3.106015
# min        0.000000     -1.000000      0.000069      0.001000     -5.477391
# 25%        0.000000     -1.000000      0.023500      8.447750      0.642709
# 50%        0.000000      1.000000      0.171000     15.200000      1.835875
# 75%        0.000000      1.000000      0.752000     24.500000      4.639156
# max        1.000000      1.000000      1.000000     81.000000     34.236720

# %%
df_categorical=pd.DataFrame()
for i in range(len(df.columns)):
    if (df.dtypes[i]==object):
        df[df.columns[i]]=df[df.columns[i]].astype('str')
        if(len(np.unique(df[df.columns[i]]))<30):
            df_categorical[df.columns[i]]=df[df.columns[i]]

# %%
plt.close('all')
df.hist(figsize=(20, 20), bins=50, xlabelsize=8, ylabelsize=8);
plt.show()

# %%
plt.close('all')
for c in df_categorical.columns:
    sns.countplot(x=df_categorical[c], data=df_categorical, palette="Greens_d")
    plt.figure(figsize=(20,20))
    plt.show()

# %%
import seaborn as sns
sns.boxplot(x=df['ORIGIN'])

# %%
sns.boxplot(x=df['CADD_PHRED'])

# %%
sns.boxplot(x=df['CADD_RAW'])

# %%
sns.boxplot(x=df['LoFtool'])

# %%
sns.boxplot(x=df['POS'])

# %%
from matplotlib.pyplot import cm
plt.close('all')
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), vmax=.8, square=True, cmap=cm.coolwarm)
plt.show()

# %%
#for correlation between the categorical variables, refer to the analysis notebook
